# %% [markdown]
# <a href="https://colab.research.google.com/github/Yelstin28/IA-Colaboratory_ULEAM/blob/main/PracticaPandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
url='https://raw.githubusercontent.com/Sinchiguano/chicagoUniversity/main/cta_Ridership.csv'
cta_rider=pd.read_csv(url)
print(rider.columns)
# Out:
# Index(['station_id', 'stationname', 'date', 'daytype', 'rides'], dtype='object')

# %%
from pandas.core.dtypes.dtypes import dtypes
#BASIC EXPLORATION
# for basic exploration, we suggest to use shape, head(), tail(), dtypes, type() modul
# your code here
print(rider.head)
print(rider.columns)
# Out:
# <bound method NDFrame.head of          station_id        stationname        date daytype  rides
# 0             41280     Jefferson Park  12/22/2017       W   6104
# 1             41000   Cermak-Chinatown  12/18/2017       W   3636
# 2             40280       Central-Lake  12/02/2017       A   1270
# 3             40140    Dempster-Skokie  12/19/2017       W   1759
# 4             40690           Dempster  12/03/2017       U    499
# ...             ...                ...         ...     ...    ...
# 1145581       41700  Washington/Wabash  12/27/2022       W   3991
# 1145582       41700  Washington/Wabash  12/28/2022       W   4100
# 1145583       41700  Washington/Wabash  12/29/2022       W   4741
# 1145584       41700  Washington/Wabash  12/30/2022       W   4664
# 1145585       41700  Washington/Wabash  12/31/2022       A   2774
#
# [1145586 rows x 5 columns]>
# Index(['station_id', 'stationname', 'date', 'daytype', 'rides'], dtype='object')

# %%
#What are some basic statistics about the data?
# use the describe module
# your code here
cta_rider['rides'].describe()
# Out:
# count    1.145586e+06
# mean     3.056635e+03
# std      3.118576e+03
# min      0.000000e+00
# 25%      9.630000e+02
# 50%      2.004000e+03
# 75%      4.025000e+03
# max      3.632300e+04
# Name: rides, dtype: float64

# %%
# use the min() and max() modules
# your code here
#min
print('Min: ',rider['rides'].min())
# Out:
# Min:  0

# %%
#max
print('Max: ',rider['rides'].max())
# Out:
# Max:  36323

# %%
#Create a Time Index
#So we have all rides from January 1, 2001 to December 31, 2019. Let's do some statistics that group ride statistics by date. First we need to tell
#your code here
cta_rider['date'] = pd.to_datetime(cta_rider['date'])
start_date = pd.to_datetime('2001-01-01')
end_date = pd.to_datetime('2019-12-31')
filtered_rider = cta_rider[(cta_rider['date'] >= start_date) & (cta_rider['date'] <= end_date)]
filtered_rider.set_index('date', inplace=True)
print(filtered_rider)
# Out:
#             station_id       stationname daytype  rides
# date
# 2017-12-22       41280    Jefferson Park       W   6104
# 2017-12-18       41000  Cermak-Chinatown       W   3636
# 2017-12-02       40280      Central-Lake       A   1270
# 2017-12-19       40140   Dempster-Skokie       W   1759
# 2017-12-03       40690          Dempster       U    499
# ...                ...               ...     ...    ...
# 2008-07-03       40030      Pulaski-Lake       W   2523
# 2014-04-25       40760         Granville       W   5085
# 2010-12-22       40830              18th       W   1464
# 2009-05-13       40040      Quincy/Wells       W   7269
# 2004-10-01       41240    Addison-O'Hare       W   3099
#
# [988858 rows x 4 columns]

# %%
# hint, sort_values(by='date')
# your code here
rider2 = filtered_rider.sort_values('date')
print(rider2)
# Out:
#             station_id           stationname daytype  rides
# date
# 2001-01-01       40810        Medical Center       U    479
# 2001-01-01       41120    35-Bronzeville-IIT       U    448
# 2001-01-01       40230            Cumberland       U    788
# 2001-01-01       40710      Chicago/Franklin       U    384
# 2001-01-01       41250      Central-Evanston       U    180
# ...                ...                   ...     ...    ...
# 2019-12-31       40180  Oak Park-Forest Park       W    928
# 2019-12-31       40400                 Noyes       W    310
# 2019-12-31       41030                  Polk       W   1256
# 2019-12-31       40750         Harlem-O'Hare       W   1602
# 2019-12-31       40900                Howard       W   3881
#
# [988858 rows x 4 columns]

# %%
# hint, use filter like this df['stationname']=='Garfield-South Elevated']
# your code here
Garfield_Dan_Ryan = cta_rider[rider['stationname'] == 'Garfield-Dan Ryan']
Garfield_South_Elevated = cta_rider[cta_rider['stationname'] == 'Garfield-South Elevated']

# %%
# hint, sort_values(by='date')
# your code here
cta_Ridership = filtered_rider.sort_values('date')
print(cta_Ridership)

# %%
#Visualizing Timeseries Data
import matplotlib.pyplot as plt
import seaborn as sns

sns.set(rc={'figure.figsize':(10, 2)})
Garfield_Dan_Ryan['rides'].plot(linewidth=0.5)
plt.show()

sns.set(rc={'figure.figsize':(10, 2)})
Garfield_South_Elevated['rides'].plot(linewidth=0.5)
plt.show()
